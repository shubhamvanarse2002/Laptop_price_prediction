# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read csv
df = pd.read_csv("laptop_data.csv")

# %%
#first
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
#get duplicate in sum
df.duplicated().sum()
# Out:
# 0

# %%
# quick overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
#to obtain the shape of a DataFrame.For example, if a DataFrame has a shape of (80, 10) , this implies that the DataFrame is made up of 80 rows and 10 columns of data.
df.shape
# Out:
# (1303, 12)

# %%
#get the null values
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
#drop the unnamed column
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
#removed the GB and kg by using replace
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
#checked the removed one
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
#change the type of ram and weight as they are objects
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
#check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
#check the price range
#import seaborn
import seaborn as sns
import matplotlib as plt

# %%
#the graph plotting
sns.distplot(df['Price'])
# Out:
# <ipython-input-14-624a6ef96d3c>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
#to check no. of company's of laptop
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#graph about price wise company name
sns.barplot(x=df['Company'],y=df['Price'])
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
#to look for typename about laptops
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#graph about price wise typename 
sns.barplot(x=df['TypeName'],y=df['Price'])
# Out:
# <Axes: xlabel='TypeName', ylabel='Price'>

# %%
#get the inches wise
sns.displot(df['Inches'])

# %%
#inches wise price
sns.scatterplot(x=df['Inches'], y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
#firstly get the value type about screen resolution
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
#get the diff column about of touchscreen laptops
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
#look for it
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 1058    Dell  2 in 1 Convertible    13.3
# 798   Lenovo  2 in 1 Convertible    13.9
# 909       LG           Ultrabook    14.0
# 1113      HP           Ultrabook    13.3
# 353       HP         Workstation    15.6
#
#                                ScreenResolution                          Cpu  \
# 1058  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# 798   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# 909   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# 1113                          Full HD 1920x1080   Intel Core i7 6500U 2.5GHz
# 353                           Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
#
#       Ram     Memory                    Gpu       OpSys  Weight        Price  \
# 1058   12  256GB SSD  Intel HD Graphics 620  Windows 10    1.60   69210.7200
# 798     8  256GB SSD  Intel HD Graphics 620  Windows 10    1.38   71874.7200
# ...

# %%
# get the no. of touchscreen and not ones
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#touchscreen wise prices
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
#get the ips column new
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
# get the no. of IPS and not ones
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#ips wise prices
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
#get the resolution into x and y axis and put into temp var named new
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
#get diff
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 980     Dell  2 in 1 Convertible    15.6
# 33      Dell           Ultrabook    13.3
# 941     Asus            Notebook    17.3
# 568   Lenovo            Notebook    15.6
# 1137    Dell            Notebook    15.6
#
#                                ScreenResolution  \
# 980   IPS Panel Full HD / Touchscreen 1920x1080
# 33             Touchscreen / Quad HD+ 3200x1800
# 941                                    1600x900
# 568                           Full HD 1920x1080
# 1137                                   1366x768
#
#                                        Cpu  Ram     Memory  \
# 980             Intel Core i7 7500U 2.7GHz   12  512GB SSD
# 33              Intel Core i7 8550U 1.8GHz   16  512GB SSD
# 941   Intel Pentium Quad Core N3710 1.6GHz    4    1TB HDD
# 568   Intel Pentium Quad Core N4200 1.1GHz    4  500GB HDD
# 1137            Intel Core i5 7200U 2.5GHz    8    1TB HDD
#
# ...

# %%
#get rid of x res into res only
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches                    ScreenResolution  \
# 224     Dell     Gaming    17.3         IPS Panel Full HD 1920x1080
# 764     Dell   Notebook    13.3                            1366x768
# 280   Lenovo   Notebook    17.3                            1600x900
# 1193   Apple  Ultrabook    12.0  IPS Panel Retina Display 2304x1440
# 1019      HP   Notebook    14.0                   Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 224   Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 764      Intel Core i3 6006U 2GHz    4             500GB HDD
# 280    Intel Core i7 7500U 2.7GHz    6  128GB SSD +  1TB HDD
# 1193          Intel Core M 1.1GHz    8   256GB Flash Storage
# 1019   Intel Core i7 6500U 2.5GHz    8             256GB SSD
#
#                           Gpu       OpSys  Weight        Price  Touchscreen  \
# 224   Nvidia GeForce GTX 1060  Windows 10    4.42  130873.7952            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
#change the type into int
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %%
#find the pairwise correlation of all columns related to prices 
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
#get the ppi
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
#again check
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
#drop the screenresolution table as its no need
df.drop(columns=['ScreenResolution'],inplace = True)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches                          Cpu  Ram  \
# 130     Dell            Notebook    15.6   Intel Core i5 7200U 2.5GHz    8
# 1265  Lenovo            Notebook    15.6  Intel Core i7 6700HQ 2.6GHz    8
# 839     Asus            Notebook    15.6   Intel Core i5 7200U 2.5GHz    8
# 674       HP  2 in 1 Convertible    14.0   Intel Core i3 7100U 2.4GHz    4
# 246       HP            Notebook    15.6   Intel Core i5 7200U 2.5GHz    8
#
#          Memory                      Gpu       OpSys  Weight       Price  \
# 130     1TB HDD       AMD Radeon R7 M445  Windows 10    2.36  34045.3872
# 1265    1TB HDD  Nvidia GeForce GTX 960M  Windows 10    2.60  47898.7200
# 839   128GB HDD    Intel HD Graphics 620  Windows 10    2.30  31435.2000
# 674   128GB SSD     Nvidia GeForce 940MX  Windows 10    1.63  37242.7200
# 246     1TB HDD    Intel HD Graphics 620  Windows 10    2.04  29783.5200
#
#       Touchscreen  Ips  X_res  Y_res         ppi
# ...

# %%
#no need of this 3 too
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %%
#now get about cpu
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
#split first 3 and extract it out
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name
# ...

# %%
#to fetch the processor
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name      Cpu brand
# ...

# %%
#get the plot
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#get the brand wise price
sns.barplot(x=df['Cpu brand'],y=df['Price'])
# Out:
# <Axes: xlabel='Cpu brand', ylabel='Price'>

# %%
#drop the cpu and cpu name column
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
#get about ram into plot
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#ram wise price
sns.barplot(x=df['Ram'],y=df['Price'])
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
#get the total count of memory
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
#diff bet all types of memory/storage 
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# <ipython-input-57-6d1ac348fc56>:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# <ipython-input-57-6d1ac348fc56>:26: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram               Memory  \
# 685     Dell              Gaming   16  256 SSD +  1000 HDD
# 318       HP            Notebook    8              256 SSD
# 1074  Lenovo           Ultrabook    8              256 SSD
# 933   Lenovo  2 in 1 Convertible   16             1000 SSD
# 423     Asus            Notebook    8             1000 HDD
#
#                           Gpu       OpSys  Weight        Price  Touchscreen  \
# 685   Nvidia GeForce GTX 1070  Windows 10    3.49  149916.6000            0
# 318     Intel HD Graphics 620  Windows 10    1.95   52214.4000            0
# 1074    Intel HD Graphics 520  Windows 10    1.30   91294.7472            1
# 933   Intel Iris Graphics 540  Windows 10    1.30   95850.7200            1
# 423      Nvidia GeForce 940MX       Linux    2.30   31808.1600            0
#
#       Ips         ppi      Cpu brand   HDD   SSD  Hybrid  Flash_Storage
# 685     0  141.211998  Intel Core i7  1000   256       0              0
# ...

# %%
#now drop the memory column
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  Hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128       0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256       0
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512       0
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# ...

# %%
#now check it again
df.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
#no need for hybrid and flash storage
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
#now get towards the gpu
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
#split the gpu conf.
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
#lets check
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
#remove arm brand
df = df[df['Gpu brand'] != 'ARM']

# %%
#check again
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
#gpu wise price
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
# Out:
# <Axes: xlabel='Gpu brand', ylabel='Price'>

# %%
#now drop the gpu column
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
#now look for the OS
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
#OS wise prices
sns.barplot(x=df['OpSys'],y=df['Price'])
# Out:
# <Axes: xlabel='OpSys', ylabel='Price'>

# %%
#diff the types of OS
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
#new column
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
#now drop the OpSys column
df.drop(columns=['OpSys'],inplace=True)

# %%
#now compare the price os wise
sns.barplot(x=df['os'],y=df['Price'])
# Out:
# <Axes: xlabel='os', ylabel='Price'>

# %%
#now get about weight
sns.distplot(df['Weight'])
# Out:
# <ipython-input-80-7b5f4589e4a3>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
#scatter plot about weight to price
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
#check
df.corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
#show the relation between variabels including time. for eg price gets high as per the ram look for the shade
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
#Natural logarithm log is the inverse of the exp(), so that log(exp(x)) = x. The natural logarithm is log in base e.
sns.distplot(np.log(df['Price']))
# Out:
# <ipython-input-84-ca945cc1ebbd>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
#here X means all columns without the price column
X = df.drop(columns=['Price'])
#here y means the log value for all the rows in the price column to get some smaller value to be in easy way
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
#The train_test_split function of the sklearn. model_selection package in Python splits arrays or matrices into random subsets for train and test data, respectively.
#so we will first import the scikit learn python library with model_selection to be the data split into train and test
from sklearn.model_selection import train_test_split
#we have gave the test size of 15% about the whole data and the random_state as we don't want to change the train dataset
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
#looking for the train dataset
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %%
#some needed libraries
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
#and more
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# Now we will perform some of the algorithms to train the dataset and compare to the test one and get the best r2_score to get the best value and mean absolute error must less to be non - correct.

# %% [markdown]
# **Linear Regression**

# %%
#Define a ColumnTransformer that applies OneHotEncoder to specific columns of the input data while passing through any columns not specified.
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

#do linear regression
step2 = LinearRegression()

#Define a pipeline that applies the ColumnTransformer and then the LinearRegression model.
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

#Fit the pipeline to the training data.
pipe.fit(X_train,y_train)

# Use the fitted pipeline to predict the target variable on the test data.
y_pred = pipe.predict(X_test)

# Print the R2 score, which measures the proportion of variance in the target variable that can be explained by the model.
print('R2 score',r2_score(y_test,y_pred))
# Print the MAE, which measures the absolute difference between the actual and predicted values of the target variable.
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073277448418629
# MAE 0.2101782797642888
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# **Ridge Regression**

# %%
# all the code is same as above only instead of using linear here we use ridge
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8127331031311809
# MAE 0.20926802242582968
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# **KNN**

# %%
# same as above only used kneighbors regression
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8009101720524295
# MAE 0.19413408395581944

# %% [markdown]
# **Decision Tree**

# %%
#used Decision tree
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8391297301197034
# MAE 0.1821086948397486

# %% [markdown]
# **Random Forest**

# %%
# used random forest
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8873402378382488
# MAE 0.15860130110457718

# %% [markdown]
# **Stacking Regressor**

# %%
# use stacking regression
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8804382155728934
# MAE 0.16695984046712425

# %% [markdown]
# **Gradient Boost**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8830212078445108
# MAE 0.15915761698758615

# %% [markdown]
# **Exporting the Model**

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...
